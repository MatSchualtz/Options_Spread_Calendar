# %% [markdown]
# # Setup

# %%
# Análise de Dados
import pandas as pd
import numpy as np

# Análise Estatística

# Data Viz

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go 
import plotly.express as px

# Financeiro
import pandas_datareader.data as web
import yfinance as yf
yf.pdr_override()
import pyfolio as pf

# %%
action = web.get_data_yahoo(['PETR4.SA'])
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=action.index, y=action['Close'].rolling(30).mean()))

# %%
# Out:
# Date
# 2000-01-03    0.338213
# 2000-01-04    0.281306
# 2000-01-05    0.271164
# 2000-01-06    0.267700
# 2000-01-07    0.272255
#                 ...
# 2024-07-22    3.635479
# 2024-07-23    3.622473
# 2024-07-24    3.630456
# 2024-07-25    3.629129
# 2024-07-26    3.628067
# Name: Adj Close, Length: 6170, dtype: float64

# %%
sns.histplot(np.log(action['Adj Close']), kde = True)
# Out:
# <Axes: xlabel='Adj Close', ylabel='Count'>
